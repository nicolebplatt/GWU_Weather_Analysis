# %% [markdown]
# ### Create set of 2,000 random locations

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# nearest city for each lat & long
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # if first time seeing city, add to city list
    if city not in cities:
        cities.append(city)
# print list length to confirm sufficient count
len(cities)
# Out:
# 800

# %%
# Import the requests library & datetime module
import requests
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call, specifying imperial = Fahrenheit
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create empty city list to hold weather data
city_data=[]
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# loop through all cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint url for each city & concatenate city name by removing blank spaces
    city_url = url +"&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # add 1 to record count
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        # not good practice to use 'pass': typically want to do something specific
          
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pokrovsk
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | skagen
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | luderitz
# Processing Record 10 of Set 1 | manaus
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | abha
# Processing Record 13 of Set 1 | lata
# Processing Record 14 of Set 1 | dharangaon
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | farafangana
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | road town
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | aykhal
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | constitucion
# Processing Record 26 of Set 1 | rio grande
# Processing Record 27 of Set 1 | maceio
# Processing Record 28 of Set 1 | champerico
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | ishigaki
# Processing Record 32 of Set 1 | arlit
# Processing Record 33 of Set 1 | marystown
# Processing Record 34 of Set 1 | monroe
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | remiremont
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | chiusi
# Processing Record 40 of Set 1 | linkou
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | tobol
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | westport
# Processing Record 50 of Set 1 | pleasantville
# Processing Record 1 of Set 2 | grand-lahou
# Processing Record 2 of Set 2 | bubaque
# Processing Record 3 of Set 2 | ardabil
# Processing Record 4 of Set 2 | vestmannaeyjar
# Processing Record 5 of Set 2 | menongue
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | avarua
# Processing Record 8 of Set 2 | yarmouth
# Processing Record 9 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | axim
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | los llanos de aridane
# Processing Record 17 of Set 2 | bestobe
# Processing Record 18 of Set 2 | nuuk
# Processing Record 19 of Set 2 | auki
# Processing Record 20 of Set 2 | damietta
# Processing Record 21 of Set 2 | collie
# Processing Record 22 of Set 2 | boueni
# Processing Record 23 of Set 2 | tsumeb
# Processing Record 24 of Set 2 | dhidhdhoo
# Processing Record 25 of Set 2 | sovetskiy
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | larsnes
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | brae
# Processing Record 30 of Set 2 | eureka
# Processing Record 31 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 2 | moctezuma
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | comodoro rivadavia
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | ushuaia
# Processing Record 37 of Set 2 | atagay
# Processing Record 38 of Set 2 | monrovia
# Processing Record 39 of Set 2 | ngunguru
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | port hardy
# Processing Record 42 of Set 2 | atlantic city
# Processing Record 43 of Set 2 | bhadrachalam
# Processing Record 44 of Set 2 | nikolayevsk-na-amure
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | aba
# Processing Record 47 of Set 2 | alice springs
# Processing Record 48 of Set 2 | kedgwick
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | husavik
# Processing Record 1 of Set 3 | kisangani
# Processing Record 2 of Set 3 | sorland
# Processing Record 3 of Set 3 | plettenberg bay
# Processing Record 4 of Set 3 | chara
# Processing Record 5 of Set 3 | masuda
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | flinders
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | elk grove
# Processing Record 11 of Set 3 | pauini
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | anadyr
# Processing Record 14 of Set 3 | salamanca
# Processing Record 15 of Set 3 | labuhan
# Processing Record 16 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | huarmey
# Processing Record 19 of Set 3 | panguna
# Processing Record 20 of Set 3 | shingu
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | puerto ayacucho
# Processing Record 23 of Set 3 | rock sound
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | port-de-paix
# City not found. Skipping...
# Processing Record 26 of Set 3 | yashan
# Processing Record 27 of Set 3 | huancabamba
# Processing Record 28 of Set 3 | cap malheureux
# Processing Record 29 of Set 3 | smolenka
# Processing Record 30 of Set 3 | ahipara
# Processing Record 31 of Set 3 | whitehorse
# Processing Record 32 of Set 3 | flin flon
# Processing Record 33 of Set 3 | nuevo progreso
# Processing Record 34 of Set 3 | henties bay
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | marsh harbour
# Processing Record 37 of Set 3 | mackenzie
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | nikolskoye
# Processing Record 40 of Set 3 | kloulklubed
# Processing Record 41 of Set 3 | esmeraldas
# Processing Record 42 of Set 3 | carnarvon
# Processing Record 43 of Set 3 | vung tau
# Processing Record 44 of Set 3 | vila velha
# Processing Record 45 of Set 3 | stephenville
# Processing Record 46 of Set 3 | falmouth
# Processing Record 47 of Set 3 | chegem
# Processing Record 48 of Set 3 | komarikhinskiy
# Processing Record 49 of Set 3 | portoroz
# Processing Record 50 of Set 3 | meulaboh
# Processing Record 1 of Set 4 | chino valley
# Processing Record 2 of Set 4 | butaritari
# Processing Record 3 of Set 4 | arraial do cabo
# Processing Record 4 of Set 4 | lorengau
# Processing Record 5 of Set 4 | dillon
# Processing Record 6 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 7 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 4 | lavrentiya
# Processing Record 9 of Set 4 | msowero
# Processing Record 10 of Set 4 | conde
# Processing Record 11 of Set 4 | novyy urengoy
# Processing Record 12 of Set 4 | cape town
# Processing Record 13 of Set 4 | opuwo
# Processing Record 14 of Set 4 | namatanai
# Processing Record 15 of Set 4 | vaini
# Processing Record 16 of Set 4 | foki
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | batagay-alyta
# Processing Record 19 of Set 4 | vanavara
# Processing Record 20 of Set 4 | saint-georges
# Processing Record 21 of Set 4 | grand gaube
# Processing Record 22 of Set 4 | hillsborough
# Processing Record 23 of Set 4 | banjar
# Processing Record 24 of Set 4 | uren
# Processing Record 25 of Set 4 | narsaq
# Processing Record 26 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 4 | araouane
# Processing Record 28 of Set 4 | lompoc
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | guozhen
# Processing Record 31 of Set 4 | fairbanks
# Processing Record 32 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 33 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 4 | buala
# Processing Record 35 of Set 4 | puerto leguizamo
# Processing Record 36 of Set 4 | harper
# Processing Record 37 of Set 4 | faya
# Processing Record 38 of Set 4 | tiksi
# Processing Record 39 of Set 4 | livingston
# Processing Record 40 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | khandyga
# Processing Record 43 of Set 4 | klaksvik
# Processing Record 44 of Set 4 | semnan
# Processing Record 45 of Set 4 | shenkursk
# Processing Record 46 of Set 4 | carmen
# Processing Record 47 of Set 4 | muros
# Processing Record 48 of Set 4 | touros
# Processing Record 49 of Set 4 | souillac
# Processing Record 50 of Set 4 | fukue
# Processing Record 1 of Set 5 | dingle
# Processing Record 2 of Set 5 | hamilton
# Processing Record 3 of Set 5 | coquimbo
# Processing Record 4 of Set 5 | salvador
# Processing Record 5 of Set 5 | sant julia de loria
# Processing Record 6 of Set 5 | blackfoot
# Processing Record 7 of Set 5 | pramanta
# Processing Record 8 of Set 5 | vincennes
# Processing Record 9 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | padilla
# Processing Record 11 of Set 5 | kahului
# Processing Record 12 of Set 5 | sibi
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | annau
# Processing Record 15 of Set 5 | saint-pierre
# Processing Record 16 of Set 5 | wanning
# Processing Record 17 of Set 5 | havre-saint-pierre
# Processing Record 18 of Set 5 | villa bruzual
# Processing Record 19 of Set 5 | hofn
# Processing Record 20 of Set 5 | portland
# Processing Record 21 of Set 5 | pisco
# Processing Record 22 of Set 5 | dzerzhinsk
# Processing Record 23 of Set 5 | gushikawa
# Processing Record 24 of Set 5 | roald
# Processing Record 25 of Set 5 | mahibadhoo
# Processing Record 26 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 27 of Set 5 | cabo san lucas
# Processing Record 28 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 5 | houma
# Processing Record 30 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 5 | victoria
# Processing Record 32 of Set 5 | tautira
# Processing Record 33 of Set 5 | dikson
# Processing Record 34 of Set 5 | sabha
# Processing Record 35 of Set 5 | ozinki
# Processing Record 36 of Set 5 | jutai
# Processing Record 37 of Set 5 | roma
# Processing Record 38 of Set 5 | bonthe
# Processing Record 39 of Set 5 | kaeo
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | asfi
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | airai
# Processing Record 44 of Set 5 | bathsheba
# Processing Record 45 of Set 5 | ilulissat
# Processing Record 46 of Set 5 | brenham
# Processing Record 47 of Set 5 | korla
# Processing Record 48 of Set 5 | nyurba
# Processing Record 49 of Set 5 | san jose
# Processing Record 50 of Set 5 | komsomolskiy
# Processing Record 1 of Set 6 | belozerskoye
# Processing Record 2 of Set 6 | kaifeng
# Processing Record 3 of Set 6 | effingham
# Processing Record 4 of Set 6 | bambous virieux
# Processing Record 5 of Set 6 | berlevag
# Processing Record 6 of Set 6 | atar
# Processing Record 7 of Set 6 | san quintin
# Processing Record 8 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 9 of Set 6 | ljungby
# Processing Record 10 of Set 6 | port hedland
# Processing Record 11 of Set 6 | pierre
# Processing Record 12 of Set 6 | shimanovsk
# Processing Record 13 of Set 6 | cherskiy
# Processing Record 14 of Set 6 | ossora
# Processing Record 15 of Set 6 | bahia de caraquez
# Processing Record 16 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 6 | samarai
# Processing Record 18 of Set 6 | hervey bay
# Processing Record 19 of Set 6 | lima
# Processing Record 20 of Set 6 | hualmay
# Processing Record 21 of Set 6 | praia
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | oranjemund
# Processing Record 24 of Set 6 | pangnirtung
# Processing Record 25 of Set 6 | saskylakh
# Processing Record 26 of Set 6 | atyrau
# Processing Record 27 of Set 6 | yuanping
# Processing Record 28 of Set 6 | east london
# Processing Record 29 of Set 6 | rochefort
# Processing Record 30 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 6 | taltal
# Processing Record 32 of Set 6 | el badari
# City not found. Skipping...
# Processing Record 33 of Set 6 | chingola
# Processing Record 34 of Set 6 | ariquemes
# Processing Record 35 of Set 6 | ust-maya
# Processing Record 36 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 6 | hovd
# Processing Record 38 of Set 6 | mehamn
# Processing Record 39 of Set 6 | onalaska
# Processing Record 40 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 41 of Set 6 | tiarei
# Processing Record 42 of Set 6 | puerto santander
# Processing Record 43 of Set 6 | torbay
# Processing Record 44 of Set 6 | rodino
# Processing Record 45 of Set 6 | sitka
# Processing Record 46 of Set 6 | mumford
# Processing Record 47 of Set 6 | sioux lookout
# Processing Record 48 of Set 6 | port elizabeth
# Processing Record 49 of Set 6 | porto novo
# Processing Record 50 of Set 6 | saint combs
# City not found. Skipping...
# Processing Record 1 of Set 7 | darasun
# Processing Record 2 of Set 7 | ostrovnoy
# Processing Record 3 of Set 7 | junction city
# Processing Record 4 of Set 7 | caracollo
# Processing Record 5 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 7 | pringsewu
# Processing Record 7 of Set 7 | newport
# Processing Record 8 of Set 7 | abu dhabi
# Processing Record 9 of Set 7 | aksu
# Processing Record 10 of Set 7 | kudahuvadhoo
# Processing Record 11 of Set 7 | oblivskaya
# Processing Record 12 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 13 of Set 7 | campoverde
# Processing Record 14 of Set 7 | akdepe
# Processing Record 15 of Set 7 | dwarka
# Processing Record 16 of Set 7 | martapura
# Processing Record 17 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 18 of Set 7 | burnie
# Processing Record 19 of Set 7 | ukiah
# Processing Record 20 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 7 | broken hill
# Processing Record 22 of Set 7 | skibotn
# Processing Record 23 of Set 7 | ushtobe
# Processing Record 24 of Set 7 | katherine
# Processing Record 25 of Set 7 | chulman
# Processing Record 26 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 7 | nioro
# Processing Record 28 of Set 7 | tezu
# Processing Record 29 of Set 7 | khuzhir
# Processing Record 30 of Set 7 | tianmen
# Processing Record 31 of Set 7 | bagdarin
# Processing Record 32 of Set 7 | college
# Processing Record 33 of Set 7 | keetmanshoop
# Processing Record 34 of Set 7 | datong
# Processing Record 35 of Set 7 | san carlos de bariloche
# Processing Record 36 of Set 7 | vestbygda
# City not found. Skipping...
# Processing Record 37 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 7 | talnakh
# Processing Record 39 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 7 | bakchar
# Processing Record 41 of Set 7 | kawerau
# Processing Record 42 of Set 7 | douglas
# Processing Record 43 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 7 | camacha
# Processing Record 46 of Set 7 | kavaratti
# Processing Record 47 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 7 | namibe
# Processing Record 49 of Set 7 | cervo
# Processing Record 50 of Set 7 | provideniya
# Processing Record 1 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 2 of Set 8 | pombia
# Processing Record 3 of Set 8 | saint-philippe
# Processing Record 4 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 8 | codrington
# Processing Record 6 of Set 8 | gizo
# Processing Record 7 of Set 8 | batie
# Processing Record 8 of Set 8 | avera
# Processing Record 9 of Set 8 | jaciara
# Processing Record 10 of Set 8 | mendi
# Processing Record 11 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 8 | hambantota
# Processing Record 13 of Set 8 | voznesenskaya
# Processing Record 14 of Set 8 | jaypur
# Processing Record 15 of Set 8 | hundested
# Processing Record 16 of Set 8 | sol-iletsk
# Processing Record 17 of Set 8 | sola
# Processing Record 18 of Set 8 | ayagoz
# Processing Record 19 of Set 8 | palmares do sul
# Processing Record 20 of Set 8 | pospelikha
# Processing Record 21 of Set 8 | shenzhen
# Processing Record 22 of Set 8 | metu
# Processing Record 23 of Set 8 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 24 of Set 8 | pinega
# Processing Record 25 of Set 8 | sarkand
# Processing Record 26 of Set 8 | soe
# Processing Record 27 of Set 8 | baruun-urt
# Processing Record 28 of Set 8 | correntina
# Processing Record 29 of Set 8 | saint-joseph
# Processing Record 30 of Set 8 | aklavik
# Processing Record 31 of Set 8 | nilanga
# Processing Record 32 of Set 8 | waddan
# Processing Record 33 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 8 | sao joao da barra
# Processing Record 35 of Set 8 | ojinaga
# Processing Record 36 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 8 | okha
# Processing Record 38 of Set 8 | beaufort
# Processing Record 39 of Set 8 | kanchanaburi
# Processing Record 40 of Set 8 | reconquista
# Processing Record 41 of Set 8 | cabedelo
# Processing Record 42 of Set 8 | banda aceh
# Processing Record 43 of Set 8 | oktyabrskiy
# Processing Record 44 of Set 8 | lo arado
# Processing Record 45 of Set 8 | la serena
# Processing Record 46 of Set 8 | herat
# Processing Record 47 of Set 8 | kupang
# Processing Record 48 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 8 | laguna
# Processing Record 50 of Set 8 | san joaquin
# Processing Record 1 of Set 9 | pochutla
# Processing Record 2 of Set 9 | garissa
# Processing Record 3 of Set 9 | mugan
# Processing Record 4 of Set 9 | gat
# Processing Record 5 of Set 9 | mount isa
# Processing Record 6 of Set 9 | padang
# Processing Record 7 of Set 9 | port blair
# Processing Record 8 of Set 9 | talaya
# Processing Record 9 of Set 9 | solnechnyy
# Processing Record 10 of Set 9 | mahajanga
# Processing Record 11 of Set 9 | doha
# Processing Record 12 of Set 9 | antofagasta
# Processing Record 13 of Set 9 | verkhnyaya sinyachikha
# Processing Record 14 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 9 | gemena
# Processing Record 16 of Set 9 | mackay
# Processing Record 17 of Set 9 | bama
# Processing Record 18 of Set 9 | ewa beach
# Processing Record 19 of Set 9 | sajanan
# Processing Record 20 of Set 9 | riyadh
# Processing Record 21 of Set 9 | abu kamal
# Processing Record 22 of Set 9 | boksitogorsk
# Processing Record 23 of Set 9 | hailar
# Processing Record 24 of Set 9 | hasaki
# Processing Record 25 of Set 9 | dedza
# Processing Record 26 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 9 | ajdabiya
# Processing Record 28 of Set 9 | manokwari
# Processing Record 29 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 30 of Set 9 | ancud
# Processing Record 31 of Set 9 | marsa matruh
# Processing Record 32 of Set 9 | santa fe
# Processing Record 33 of Set 9 | general roca
# Processing Record 34 of Set 9 | puerto colombia
# Processing Record 35 of Set 9 | gornopravdinsk
# Processing Record 36 of Set 9 | puerto gaitan
# Processing Record 37 of Set 9 | linxia
# Processing Record 38 of Set 9 | mozarlandia
# Processing Record 39 of Set 9 | zalantun
# Processing Record 40 of Set 9 | handwara
# City not found. Skipping...
# Processing Record 41 of Set 9 | mega
# Processing Record 42 of Set 9 | mindyak
# Processing Record 43 of Set 9 | paracuru
# Processing Record 44 of Set 9 | shimoda
# Processing Record 45 of Set 9 | tilichiki
# Processing Record 46 of Set 9 | gorno-altaysk
# Processing Record 47 of Set 9 | cheyenne
# Processing Record 48 of Set 9 | cravo norte
# Processing Record 49 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 9 | raudeberg
# Processing Record 1 of Set 10 | kangavar
# Processing Record 2 of Set 10 | cayenne
# Processing Record 3 of Set 10 | lisakovsk
# Processing Record 4 of Set 10 | tongren
# Processing Record 5 of Set 10 | gelemso
# Processing Record 6 of Set 10 | ca mau
# Processing Record 7 of Set 10 | botou
# Processing Record 8 of Set 10 | tsovazard
# Processing Record 9 of Set 10 | vardo
# Processing Record 10 of Set 10 | zhigansk
# Processing Record 11 of Set 10 | gilazi
# City not found. Skipping...
# Processing Record 12 of Set 10 | fort nelson
# Processing Record 13 of Set 10 | zyryanka
# Processing Record 14 of Set 10 | sungairaya
# Processing Record 15 of Set 10 | kjollefjord
# Processing Record 16 of Set 10 | kigali
# Processing Record 17 of Set 10 | mtwara
# Processing Record 18 of Set 10 | pevek
# Processing Record 19 of Set 10 | taoudenni
# Processing Record 20 of Set 10 | vilyuysk
# Processing Record 21 of Set 10 | bilma
# Processing Record 22 of Set 10 | cidreira
# Processing Record 23 of Set 10 | teeli
# Processing Record 24 of Set 10 | den helder
# Processing Record 25 of Set 10 | south lake tahoe
# Processing Record 26 of Set 10 | mangan
# Processing Record 27 of Set 10 | ekibastuz
# Processing Record 28 of Set 10 | mareeba
# Processing Record 29 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 10 | ruteng
# Processing Record 31 of Set 10 | miajadas
# Processing Record 32 of Set 10 | houston
# Processing Record 33 of Set 10 | acarau
# Processing Record 34 of Set 10 | majene
# Processing Record 35 of Set 10 | booue
# Processing Record 36 of Set 10 | port augusta
# Processing Record 37 of Set 10 | meridian
# Processing Record 38 of Set 10 | yeppoon
# Processing Record 39 of Set 10 | port townsend
# Processing Record 40 of Set 10 | port lincoln
# Processing Record 41 of Set 10 | mananjary
# Processing Record 42 of Set 10 | khani
# Processing Record 43 of Set 10 | yulara
# Processing Record 44 of Set 10 | rio brilhante
# Processing Record 45 of Set 10 | shasta lake
# Processing Record 46 of Set 10 | griffith
# Processing Record 47 of Set 10 | toguchin
# Processing Record 48 of Set 10 | coihaique
# Processing Record 49 of Set 10 | nabire
# Processing Record 50 of Set 10 | port hawkesbury
# Processing Record 1 of Set 11 | ratnagiri
# Processing Record 2 of Set 11 | ballina
# Processing Record 3 of Set 11 | cockburn town
# Processing Record 4 of Set 11 | saint-ambroise
# Processing Record 5 of Set 11 | mogadishu
# Processing Record 6 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 11 | nantucket
# Processing Record 8 of Set 11 | taman
# Processing Record 9 of Set 11 | barcelos
# Processing Record 10 of Set 11 | tura
# Processing Record 11 of Set 11 | orumiyeh
# Processing Record 12 of Set 11 | parrita
# Processing Record 13 of Set 11 | salalah
# Processing Record 14 of Set 11 | porbandar
# Processing Record 15 of Set 11 | balkhash
# Processing Record 16 of Set 11 | shadrinsk
# Processing Record 17 of Set 11 | kaiyuan
# Processing Record 18 of Set 11 | vostok
# Processing Record 19 of Set 11 | lingao
# Processing Record 20 of Set 11 | mecca
# Processing Record 21 of Set 11 | hwange
# Processing Record 22 of Set 11 | itarema
# Processing Record 23 of Set 11 | caraballeda
# Processing Record 24 of Set 11 | jacareacanga
# Processing Record 25 of Set 11 | esperance
# Processing Record 26 of Set 11 | coahuayana
# Processing Record 27 of Set 11 | klyuchi
# Processing Record 28 of Set 11 | belgaum
# Processing Record 29 of Set 11 | forbes
# Processing Record 30 of Set 11 | raga
# Processing Record 31 of Set 11 | cosala
# Processing Record 32 of Set 11 | paraguacu paulista
# Processing Record 33 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 35 of Set 11 | gasa
# Processing Record 36 of Set 11 | paungde
# Processing Record 37 of Set 11 | galesong
# Processing Record 38 of Set 11 | mao
# Processing Record 39 of Set 11 | belmonte
# Processing Record 40 of Set 11 | borgo san dalmazzo
# Processing Record 41 of Set 11 | toda bhim
# City not found. Skipping...
# Processing Record 42 of Set 11 | ler
# Processing Record 43 of Set 11 | isangel
# Processing Record 44 of Set 11 | kruisfontein
# Processing Record 45 of Set 11 | mount gambier
# Processing Record 46 of Set 11 | cangucu
# Processing Record 47 of Set 11 | beyneu
# Processing Record 48 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 11 | asau
# Processing Record 50 of Set 11 | celestun
# Processing Record 1 of Set 12 | severo-kurilsk
# Processing Record 2 of Set 12 | basoko
# Processing Record 3 of Set 12 | eenhana
# Processing Record 4 of Set 12 | lasa
# Processing Record 5 of Set 12 | ust-abakan
# Processing Record 6 of Set 12 | ternate
# Processing Record 7 of Set 12 | abu samrah
# Processing Record 8 of Set 12 | honningsvag
# Processing Record 9 of Set 12 | lebu
# Processing Record 10 of Set 12 | paamiut
# Processing Record 11 of Set 12 | camana
# Processing Record 12 of Set 12 | christchurch
# Processing Record 13 of Set 12 | dickinson
# Processing Record 14 of Set 12 | tacuarembo
# Processing Record 15 of Set 12 | varosfold
# City not found. Skipping...
# Processing Record 16 of Set 12 | sungaipenuh
# Processing Record 17 of Set 12 | fare
# Processing Record 18 of Set 12 | mana
# Processing Record 19 of Set 12 | boa vista
# Processing Record 20 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 12 | kununurra
# Processing Record 22 of Set 12 | vila franca do campo
# Processing Record 23 of Set 12 | mandera
# Processing Record 24 of Set 12 | lyubar
# Processing Record 25 of Set 12 | macieira de cambra
# Processing Record 26 of Set 12 | karasjok
# Processing Record 27 of Set 12 | leopold
# Processing Record 28 of Set 12 | bandarbeyla
# Processing Record 29 of Set 12 | canutama
# Processing Record 30 of Set 12 | iwaki
# Processing Record 31 of Set 12 | kudat
# Processing Record 32 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 12 | sechura
# Processing Record 34 of Set 12 | hanmer springs
# Processing Record 35 of Set 12 | crewe
# Processing Record 36 of Set 12 | margate
# Processing Record 37 of Set 12 | inongo
# Processing Record 38 of Set 12 | havoysund
# Processing Record 39 of Set 12 | catemaco
# Processing Record 40 of Set 12 | dalianwan
# Processing Record 41 of Set 12 | kyzyl-suu
# Processing Record 42 of Set 12 | san policarpo
# Processing Record 43 of Set 12 | saint-augustin
# Processing Record 44 of Set 12 | udayagiri
# Processing Record 45 of Set 12 | graaff-reinet
# Processing Record 46 of Set 12 | san ignacio
# Processing Record 47 of Set 12 | mandalgovi
# Processing Record 48 of Set 12 | malaya serdoba
# Processing Record 49 of Set 12 | visby
# Processing Record 50 of Set 12 | leningradskiy
# Processing Record 1 of Set 13 | puerto baquerizo moreno
# Processing Record 2 of Set 13 | trairi
# Processing Record 3 of Set 13 | miramar
# Processing Record 4 of Set 13 | kachiry
# Processing Record 5 of Set 13 | fasa
# Processing Record 6 of Set 13 | cabinda
# Processing Record 7 of Set 13 | pingdingshan
# Processing Record 8 of Set 13 | alofi
# Processing Record 9 of Set 13 | fort saint james
# Processing Record 10 of Set 13 | libourne
# Processing Record 11 of Set 13 | sacramento
# Processing Record 12 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 13 | tuatapere
# Processing Record 14 of Set 13 | kimberley
# Processing Record 15 of Set 13 | te anau
# Processing Record 16 of Set 13 | cherrapunji
# Processing Record 17 of Set 13 | tandil
# Processing Record 18 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 19 of Set 13 | saldanha
# Processing Record 20 of Set 13 | lagoa
# Processing Record 21 of Set 13 | abyek
# Processing Record 22 of Set 13 | grootfontein
# Processing Record 23 of Set 13 | fortuna
# Processing Record 24 of Set 13 | tailai
# Processing Record 25 of Set 13 | ulaanbaatar
# Processing Record 26 of Set 13 | deputatskiy
# Processing Record 27 of Set 13 | hobyo
# Processing Record 28 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 13 | usakos
# Processing Record 30 of Set 13 | sabang
# Processing Record 31 of Set 13 | jiwani
# Processing Record 32 of Set 13 | hirara
# Processing Record 33 of Set 13 | cheremshan
# Processing Record 34 of Set 13 | dafeng
# Processing Record 35 of Set 13 | moerai
# Processing Record 36 of Set 13 | esterhazy
# Processing Record 37 of Set 13 | rohru
# Processing Record 38 of Set 13 | manzhouli
# Processing Record 39 of Set 13 | igarka
# Processing Record 40 of Set 13 | sucre
# Processing Record 41 of Set 13 | bushenyi
# Processing Record 42 of Set 13 | kargopol
# Processing Record 43 of Set 13 | storforshei
# Processing Record 44 of Set 13 | bud
# Processing Record 45 of Set 13 | binzhou
# Processing Record 46 of Set 13 | vila do maio
# Processing Record 47 of Set 13 | talcahuano
# Processing Record 48 of Set 13 | waingapu
# Processing Record 49 of Set 13 | hluti
# Processing Record 50 of Set 13 | qasigiannguit
# Processing Record 1 of Set 14 | naze
# Processing Record 2 of Set 14 | huangzhai
# Processing Record 3 of Set 14 | ambilobe
# Processing Record 4 of Set 14 | benghazi
# Processing Record 5 of Set 14 | xam nua
# Processing Record 6 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 14 | glodeni
# Processing Record 8 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 14 | quelimane
# Processing Record 10 of Set 14 | ponta delgada
# Processing Record 11 of Set 14 | seydi
# Processing Record 12 of Set 14 | nerchinskiy zavod
# Processing Record 13 of Set 14 | fonte boa
# Processing Record 14 of Set 14 | marawi
# Processing Record 15 of Set 14 | erenhot
# Processing Record 16 of Set 14 | pietersburg
# Processing Record 17 of Set 14 | karratha
# Processing Record 18 of Set 14 | burica
# City not found. Skipping...
# Processing Record 19 of Set 14 | asyut
# Processing Record 20 of Set 14 | aliwal north
# Processing Record 21 of Set 14 | duz
# City not found. Skipping...
# Processing Record 22 of Set 14 | vieste
# Processing Record 23 of Set 14 | maba
# Processing Record 24 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 14 | jalu
# Processing Record 26 of Set 14 | pacific grove
# Processing Record 27 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 14 | nola
# Processing Record 29 of Set 14 | cascais
# Processing Record 30 of Set 14 | wattegama
# Processing Record 31 of Set 14 | norman wells
# Processing Record 32 of Set 14 | santa vitoria
# Processing Record 33 of Set 14 | setermoen
# Processing Record 34 of Set 14 | malpe
# Processing Record 35 of Set 14 | egvekinot
# Processing Record 36 of Set 14 | mehran
# Processing Record 37 of Set 14 | punta de piedra
# Processing Record 38 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 14 | najran
# Processing Record 40 of Set 14 | baboua
# City not found. Skipping...
# Processing Record 41 of Set 14 | were ilu
# Processing Record 42 of Set 14 | silifke
# Processing Record 43 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 14 | atambua
# Processing Record 45 of Set 14 | uchiza
# Processing Record 46 of Set 14 | chunskiy
# Processing Record 47 of Set 14 | kalmar
# Processing Record 48 of Set 14 | port macquarie
# Processing Record 49 of Set 14 | villa carlos paz
# Processing Record 50 of Set 14 | necochea
# Processing Record 1 of Set 15 | kalianget
# Processing Record 2 of Set 15 | rafai
# Processing Record 3 of Set 15 | coos bay
# Processing Record 4 of Set 15 | sompeta
# Processing Record 5 of Set 15 | severnoye
# Processing Record 6 of Set 15 | caravelas
# Processing Record 7 of Set 15 | aswan
# Processing Record 8 of Set 15 | merauke
# Processing Record 9 of Set 15 | half moon bay
# Processing Record 10 of Set 15 | mizpe ramon
# City not found. Skipping...
# Processing Record 11 of Set 15 | san cristobal
# Processing Record 12 of Set 15 | ahtopol
# Processing Record 13 of Set 15 | maniitsoq
# Processing Record 14 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 15 | hami
# Processing Record 16 of Set 15 | snasa
# Processing Record 17 of Set 15 | qrendi
# Processing Record 18 of Set 15 | nome
# Processing Record 19 of Set 15 | koroni
# Processing Record 20 of Set 15 | manado
# Processing Record 21 of Set 15 | catuday
# Processing Record 22 of Set 15 | bloemfontein
# Processing Record 23 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 24 of Set 15 | vila
# Processing Record 25 of Set 15 | urengoy
# Processing Record 26 of Set 15 | aden
# Processing Record 27 of Set 15 | seoul
# Processing Record 28 of Set 15 | dudinka
# Processing Record 29 of Set 15 | redmond
# Processing Record 30 of Set 15 | savinskiy
# Processing Record 31 of Set 15 | liverpool
# Processing Record 32 of Set 15 | talavera de la reina
# Processing Record 33 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 34 of Set 15 | zhuanghe
# Processing Record 35 of Set 15 | belyy yar
# Processing Record 36 of Set 15 | mooi river
# City not found. Skipping...
# Processing Record 37 of Set 15 | yaan
# Processing Record 38 of Set 15 | zabolotiv
# Processing Record 39 of Set 15 | kurmanayevka
# Processing Record 40 of Set 15 | humboldt
# Processing Record 41 of Set 15 | nara
# Processing Record 42 of Set 15 | bereda
# Processing Record 43 of Set 15 | southbridge
# Processing Record 44 of Set 15 | lebowakgomo
# Processing Record 45 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 46 of Set 15 | san andres
# Processing Record 47 of Set 15 | lubao
# Processing Record 48 of Set 15 | viedma
# Processing Record 49 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 50 of Set 15 | mayo
# Processing Record 1 of Set 16 | akyab
# Processing Record 2 of Set 16 | haines junction
# Processing Record 3 of Set 16 | chumikan
# Processing Record 4 of Set 16 | manama
# Processing Record 5 of Set 16 | kinlochleven
# Processing Record 6 of Set 16 | sorong
# Processing Record 7 of Set 16 | anapskaya
# Processing Record 8 of Set 16 | halifax
# Processing Record 9 of Set 16 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 16 | neiafu
# Processing Record 11 of Set 16 | ankang
# Processing Record 12 of Set 16 | mampong
# Processing Record 13 of Set 16 | waren
# Processing Record 14 of Set 16 | beira
# Processing Record 15 of Set 16 | nizwa
# Processing Record 16 of Set 16 | plunge
# Processing Record 17 of Set 16 | manoharpur
# Processing Record 18 of Set 16 | srednekolymsk
# Processing Record 19 of Set 16 | abalak
# Processing Record 20 of Set 16 | nadym
# Processing Record 21 of Set 16 | tomari
# Processing Record 22 of Set 16 | bilibino
# Processing Record 23 of Set 16 | bani walid
# Processing Record 24 of Set 16 | rutana
# Processing Record 25 of Set 16 | xining
# Processing Record 26 of Set 16 | gorontalo
# Processing Record 27 of Set 16 | dromolaxia
# Processing Record 28 of Set 16 | mafinga
# Processing Record 29 of Set 16 | lakes entrance
# Processing Record 30 of Set 16 | micesti
# Processing Record 31 of Set 16 | richards bay
# Processing Record 32 of Set 16 | kilindoni
# Processing Record 33 of Set 16 | ongandjera
# Processing Record 34 of Set 16 | challapata
# Processing Record 35 of Set 16 | yumen
# Processing Record 36 of Set 16 | tena
# Processing Record 37 of Set 16 | nago
# Processing Record 38 of Set 16 | fort-shevchenko
# Processing Record 39 of Set 16 | santa engracia
# Processing Record 40 of Set 16 | bosaso
# Processing Record 41 of Set 16 | lake city
# Processing Record 42 of Set 16 | ilabaya
# Processing Record 43 of Set 16 | fuxin
# Processing Record 44 of Set 16 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 16 | tanout
# Processing Record 46 of Set 16 | barranca
# Processing Record 47 of Set 16 | vydrino
# Processing Record 48 of Set 16 | san matias
# Processing Record 49 of Set 16 | tenenkou
# Processing Record 50 of Set 16 | luau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert array of dictionaries to pandas df
# I know the instructions did not need date but I included for quality control reasons.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Pokrovsk  48.2820   37.1758     61.92        38         100
# 1         Mataura -46.1927  168.8643     53.55        98         100
# 2         Rikitea -23.1203 -134.9692     78.96        68          78
# 3    Longyearbyen  78.2186   15.6401     12.04        62           0
# 4   Mar Del Plata -38.0023  -57.5575     52.88        85          40
# 5  Ribeira Grande  38.5167  -28.7000     64.80        88          75
# 6          Skagen  57.7209   10.5839     34.75        42           0
# 7    Punta Arenas -53.1500  -70.9167     46.51        73          75
# 8        Luderitz -26.6481   15.1594     71.56        64           0
# 9          Manaus  -3.1019  -60.0250     79.29        89          75
#
#    Wind Speed Country Current Description                 Date
# 0       13.82      UA     overcast clouds  2022-03-30 13:06:48
# 1        1.19      NZ     overcast clouds  2022-03-30 13:09:35
# 2        9.26      PF       broken clouds  2022-03-30 13:09:36
# 3        5.75      SJ           clear sky  2022-03-30 13:09:36
# 4       12.66      AR       moderate rain  2022-03-30 13:09:36
# 5        4.61      PT       broken clouds  2022-03-30 13:09:37
# 6        7.43      DK           clear sky  2022-03-30 13:09:37
# 7       11.50      CL       broken clouds  2022-03-30 13:09:38
# 8       24.07      NA           clear sky  2022-03-30 13:09:38
# 9        4.61      BR          light rain  2022-03-30 13:07:17

# %%
# change column order
new_column_order = ["City","Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0       Pokrovsk      UA  2022-03-30 13:06:48  48.2820   37.1758     61.92
# 1        Mataura      NZ  2022-03-30 13:09:35 -46.1927  168.8643     53.55
# 2        Rikitea      PF  2022-03-30 13:09:36 -23.1203 -134.9692     78.96
# 3   Longyearbyen      SJ  2022-03-30 13:09:36  78.2186   15.6401     12.04
# 4  Mar Del Plata      AR  2022-03-30 13:09:36 -38.0023  -57.5575     52.88
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        38         100       13.82     overcast clouds
# 1        98         100        1.19     overcast clouds
# 2        68          78        9.26       broken clouds
# 3        62           0        5.75           clear sky
# 4        85          40       12.66       moderate rain

# %%
# create csv output file
output_data = "WeatherPy_Database.csv"
# export data into csv
city_data_df.to_csv(output_data, index_label="City_ID")
